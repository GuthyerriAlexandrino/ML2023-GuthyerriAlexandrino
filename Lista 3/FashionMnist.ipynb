# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

train = np.array(pd.read_csv("/content/drive/MyDrive/Fashion/fashion-mnist_train.csv"))
test = np.array(pd.read_csv("/content/drive/MyDrive/Fashion/fashion-mnist_test.csv"))

X_train = train[:, 1:]
y_train = np.ravel(train[:, 0:1])
X_test = test[:, 1:]
y_test = np.ravel(test[:, 0:1])

(trainData, valData, trainLabels, valLabels) = train_test_split(X_train, y_train,
test_size=0.3, random_state=84)

kVals = range(1, 30, 1)
accuracies = []

for k in kVals:
    # train the k-Nearest Neighbor classifier with the current value of `k`
    model = KNeighborsClassifier(n_neighbors=k, metric='euclidean')
    model.fit(trainData, trainLabels)
    # evaluate the model and update the accuracies list
    score = model.score(valData, valLabels)
    print("k=%d, accuracy=%.2f%%" % (k, score * 100))
    accuracies.append(score)

plt.plot(kVals, accuracies)
# Out:
# k=1, accuracy=84.69%
# k=2, accuracy=84.73%
# k=3, accuracy=85.20%
# k=4, accuracy=85.43%
# k=5, accuracy=85.28%
# k=6, accuracy=85.46%
# k=7, accuracy=85.37%
# k=8, accuracy=85.21%
# k=9, accuracy=84.97%
# k=10, accuracy=84.76%
# k=11, accuracy=84.68%
# k=12, accuracy=84.63%
# k=13, accuracy=84.42%
# k=14, accuracy=84.52%
# k=15, accuracy=84.45%
# k=16, accuracy=84.26%
# k=17, accuracy=84.23%
# k=18, accuracy=84.23%
# k=19, accuracy=84.02%
# k=20, accuracy=83.99%
# k=21, accuracy=83.86%
# k=22, accuracy=83.72%
# k=23, accuracy=83.71%
# k=24, accuracy=83.68%
# k=25, accuracy=83.73%
# k=26, accuracy=83.62%
# k=27, accuracy=83.51%
# k=28, accuracy=83.51%
# k=29, accuracy=83.44%
